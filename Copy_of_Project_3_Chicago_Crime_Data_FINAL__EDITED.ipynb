# %% [markdown]
# <a href="https://colab.research.google.com/github/Josey1/Data_Viz/blob/main/Copy_of_Project_3_Chicago_Crime_Data_FINAL__EDITED.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Part 1

# %%
#mounting my drive
#mounting drive to read saved file with the data that was provided
# Mount google drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
#Loading necessary packages
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
import matplotlib.ticker as mticks
import seaborn as sns

import missingno as miss
import datetime as dt
import statsmodels.tsa.api as tsa

# %%
#Loading individual datasets for analyis (Failed to upload the zipped one at once because of the size)
#Loading the data"

df1 = pd.read_csv("/content/drive/MyDrive/Data/Chicago-Crime_2001.csv")
df2 = pd.read_csv("/content/drive/MyDrive/Data/Chicago-Crime_2002.csv")
df3 = pd.read_csv("/content/drive/MyDrive/Data/Chicago-Crime_2003.csv")
df4 = pd.read_csv("/content/drive/MyDrive/Data/Chicago-Crime_2004.csv")
df5 = pd.read_csv("/content/drive/MyDrive/Data/Chicago-Crime_2005.csv")
df6 = pd.read_csv("/content/drive/MyDrive/Data/Chicago-Crime_2006.csv")
df7 = pd.read_csv("/content/drive/MyDrive/Data/Chicago-Crime_2007.csv")
df8 = pd.read_csv("/content/drive/MyDrive/Data/Chicago-Crime_2008.csv")
df9 = pd.read_csv("/content/drive/MyDrive/Data/Chicago-Crime_2009.csv")
df10 = pd.read_csv("/content/drive/MyDrive/Data/Chicago-Crime_2010.csv")
df11 = pd.read_csv("/content/drive/MyDrive/Data/Chicago-Crime_2011.csv")
df12 = pd.read_csv("/content/drive/MyDrive/Data/Chicago-Crime_2012.csv")
df13 = pd.read_csv("/content/drive/MyDrive/Data/Chicago-Crime_2013.csv")
df14 = pd.read_csv("/content/drive/MyDrive/Data/Chicago-Crime_2014.csv")
df15 = pd.read_csv("/content/drive/MyDrive/Data/Chicago-Crime_2015.csv")
df16 = pd.read_csv("/content/drive/MyDrive/Data/Chicago-Crime_2016.csv")
df17 = pd.read_csv("/content/drive/MyDrive/Data/Chicago-Crime_2017.csv")
df18 = pd.read_csv("/content/drive/MyDrive/Data/Chicago-Crime_2018.csv")
df19 = pd.read_csv("/content/drive/MyDrive/Data/Chicago-Crime_2019.csv")
df20 = pd.read_csv("/content/drive/MyDrive/Data/Chicago-Crime_2020.csv")
df21= pd.read_csv("/content/drive/MyDrive/Data/Chicago-Crime_2021.csv")
df22 = pd.read_csv("/content/drive/MyDrive/Data/Chicago-Crime_2022.csv")

# %%
#Displaying the information for my dataframes
df_names = ['df1', 'df2', 'df3','df4','df5','df6','df7','df8','df9','df10','df11','df12','df13','df14','df15','df16','df17','df18','df19','df20','df21','df22']

# Iterate through DataFrame names and display .info() for each DataFrame
for df_name in df_names:
    print("Info for DataFrame:", df_name)
    print(eval(df_name).info())
    print("--------------------------------------------")
# Out:
# Info for DataFrame: df1
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 485886 entries, 0 to 485885
# Data columns (total 12 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   ID                    485886 non-null  int64
#  1   Date                  485886 non-null  object
#  2   Primary Type          485886 non-null  object
#  3   Description           485886 non-null  object
#  4   Location Description  485881 non-null  object
#  5   Arrest                485886 non-null  bool
#  6   Domestic              485886 non-null  bool
#  7   Beat                  485886 non-null  int64
#  8   District              485886 non-null  float64
#  9   Ward                  4303 non-null    float64
#  10  Latitude              482876 non-null  float64
#  11  Longitude             482876 non-null  float64
# dtypes: bool(2), float64(4), int64(2), object(4)
# memory usage: 38.0+ MB
# None
# ...

# %%
#Since the data frames have the same features, i will display .head() for one dataframe to have a feel of the features
df1.head()
# Out:
#         ID                    Date     Primary Type          Description  \
# 0  1326041  01/01/2001 01:00:00 AM          BATTERY               SIMPLE
# 1  1319931  01/01/2001 01:00:00 PM          BATTERY               SIMPLE
# 2  1324743  01/01/2001 01:00:00 PM         GAMBLING  ILLEGAL ILL LOTTERY
# 3  1310717  01/01/2001 01:00:00 AM  CRIMINAL DAMAGE           TO VEHICLE
# 4  1318099  01/01/2001 01:00:00 AM          BATTERY               SIMPLE
#
#       Location Description  Arrest  Domestic  Beat  District  Ward   Latitude  \
# 0                RESIDENCE   False     False  1624      16.0   NaN  41.957850
# 1                RESIDENCE   False      True   825       8.0   NaN  41.783892
# 2                   STREET    True     False   313       3.0   NaN  41.780412
# 3                   STREET   False     False  2424      24.0   NaN  42.012391
# 4  RESIDENCE PORCH/HALLWAY   False      True   214       2.0   NaN  41.819538
#
#    Longitude
# 0 -87.749185
# 1 -87.684841
# 2 -87.611970
# ...

# %%
# Converting the date column to datetime for each DataFrame
for df_name in df_names:
    print("Converting date column to datetime for DataFrame:", df_name)
    # Assuming your date column is named 'date_column' and the format is '%Y-%m-%d',
    # replace it with the actual name and format of your date column
    globals()[df_name]['Date'] = pd.to_datetime(globals()[df_name]['Date'], errors='coerce', format='%Y-%m-%d')
    print("--------------------------------------------")
# Out:
# Converting date column to datetime for DataFrame: df1
# --------------------------------------------
# Converting date column to datetime for DataFrame: df2
# --------------------------------------------
# Converting date column to datetime for DataFrame: df3
# --------------------------------------------
# Converting date column to datetime for DataFrame: df4
# --------------------------------------------
# Converting date column to datetime for DataFrame: df5
# --------------------------------------------
# Converting date column to datetime for DataFrame: df6
# --------------------------------------------
# Converting date column to datetime for DataFrame: df7
# --------------------------------------------
# Converting date column to datetime for DataFrame: df8
# --------------------------------------------
# Converting date column to datetime for DataFrame: df9
# --------------------------------------------
# Converting date column to datetime for DataFrame: df10
# ...

# %%
#Loading one dataframe  to confirm changes
df1.head()
# Out:
#         ID                Date     Primary Type          Description  \
# 0  1326041 2001-01-01 01:00:00          BATTERY               SIMPLE
# 1  1319931 2001-01-01 13:00:00          BATTERY               SIMPLE
# 2  1324743 2001-01-01 13:00:00         GAMBLING  ILLEGAL ILL LOTTERY
# 3  1310717 2001-01-01 01:00:00  CRIMINAL DAMAGE           TO VEHICLE
# 4  1318099 2001-01-01 01:00:00          BATTERY               SIMPLE
#
#       Location Description  Arrest  Domestic  Beat  District  Ward   Latitude  \
# 0                RESIDENCE   False     False  1624      16.0   NaN  41.957850
# 1                RESIDENCE   False      True   825       8.0   NaN  41.783892
# 2                   STREET    True     False   313       3.0   NaN  41.780412
# 3                   STREET   False     False  2424      24.0   NaN  42.012391
# 4  RESIDENCE PORCH/HALLWAY   False      True   214       2.0   NaN  41.819538
#
#    Longitude
# 0 -87.749185
# 1 -87.684841
# 2 -87.611970
# 3 -87.678032
# ...

# %%
#Setting the date column as the index for all my dataframes
for df_name in df_names:
    print("Setting date column as index for DataFrame:", df_name)
    # Assuming your date column is named 'date_column', replace it with the actual name of your date column
    globals()[df_name] = globals()[df_name].set_index('Date')
    print("--------------------------------------------")
# Out:
# Setting date column as index for DataFrame: df1
# --------------------------------------------
# Setting date column as index for DataFrame: df2
# --------------------------------------------
# Setting date column as index for DataFrame: df3
# --------------------------------------------
# Setting date column as index for DataFrame: df4
# --------------------------------------------
# Setting date column as index for DataFrame: df5
# --------------------------------------------
# Setting date column as index for DataFrame: df6
# --------------------------------------------
# Setting date column as index for DataFrame: df7
# --------------------------------------------
# Setting date column as index for DataFrame: df8
# --------------------------------------------
# Setting date column as index for DataFrame: df9
# --------------------------------------------
# Setting date column as index for DataFrame: df10
# --------------------------------------------
# ...

# %%
#Confirming changes with one dataframe
df1.head()
# Out:
#                           ID     Primary Type          Description  \
# Date
# 2001-01-01 01:00:00  1326041          BATTERY               SIMPLE
# 2001-01-01 13:00:00  1319931          BATTERY               SIMPLE
# 2001-01-01 13:00:00  1324743         GAMBLING  ILLEGAL ILL LOTTERY
# 2001-01-01 01:00:00  1310717  CRIMINAL DAMAGE           TO VEHICLE
# 2001-01-01 01:00:00  1318099          BATTERY               SIMPLE
#
#                         Location Description  Arrest  Domestic  Beat  \
# Date
# 2001-01-01 01:00:00                RESIDENCE   False     False  1624
# 2001-01-01 13:00:00                RESIDENCE   False      True   825
# 2001-01-01 13:00:00                   STREET    True     False   313
# 2001-01-01 01:00:00                   STREET   False     False  2424
# 2001-01-01 01:00:00  RESIDENCE PORCH/HALLWAY   False      True   214
#
#                      District  Ward   Latitude  Longitude
# Date
# 2001-01-01 01:00:00      16.0   NaN  41.957850 -87.749185
# ...

# %%
#Checking for null values in my datasets
for df_name in df_names:
    print("Number of null values in DataFrame:", df_name)
    # Calculate the number of null values in each column
    null_counts = globals()[df_name].isnull().sum()
    print(null_counts)
    print("--------------------------------------------")
# Out:
# Number of null values in DataFrame: df1
# ID                           0
# Primary Type                 0
# Description                  0
# Location Description         5
# Arrest                       0
# Domestic                     0
# Beat                         0
# District                     0
# Ward                    481583
# Latitude                  3010
# Longitude                 3010
# dtype: int64
# --------------------------------------------
# Number of null values in DataFrame: df2
# ID                           0
# Primary Type                 0
# Description                  0
# Location Description         5
# Arrest                       0
# Domestic                     0
# Beat                         0
# District                     0
# Ward                    133110
# Latitude                 15276
# Longitude                15276
# dtype: int64
# --------------------------------------------
# Number of null values in DataFrame: df3
# ...

# %% [markdown]
# Topic 1) Comparing Police Districts
#
# Which district had the most crimes in 2022?
#
# Which had the least?
#
# Topic 2) Crimes Across the Years:
#
# Is the total number of crimes increasing or decreasing across the years?
#
# Are there any individual crimes that are doing the opposite (e.g., decreasing when overall crime is increasing or vice-versa)?
# ​
#
# Topic 4) Comparing Months:
#
# Answer the question: ​What months have the most crime? What months have the least?
#
# Answer the question: Are there any individual crimes that do not follow this pattern? If so, which crimes?

# %%
#Focusing on the topics, i want to answer, i am going to filter out only the necessary columns
# I am going to keep a few columns to answer the questions above ;Primary Type; Description, Ward, Arrest, Domestic  and District                    0
# will impute missing values for District and Ward with the most frequent value
# Specify the columns you want to keep

columns_to_keep = ['Primary Type', 'Description', 'Ward','Arrest','Domestic','District']

# Keeping specified columns for all my dataframes
for df_name in df_names:
    print("Keeping specific columns for DataFrame:", df_name)
    # Assuming your DataFrame is stored in a variable named df
    globals()[df_name] = globals()[df_name].loc[:, columns_to_keep]
    print("--------------------------------------------")
# Out:
# Keeping specific columns for DataFrame: df1
# --------------------------------------------
# Keeping specific columns for DataFrame: df2
# --------------------------------------------
# Keeping specific columns for DataFrame: df3
# --------------------------------------------
# Keeping specific columns for DataFrame: df4
# --------------------------------------------
# Keeping specific columns for DataFrame: df5
# --------------------------------------------
# Keeping specific columns for DataFrame: df6
# --------------------------------------------
# Keeping specific columns for DataFrame: df7
# --------------------------------------------
# Keeping specific columns for DataFrame: df8
# --------------------------------------------
# Keeping specific columns for DataFrame: df9
# --------------------------------------------
# Keeping specific columns for DataFrame: df10
# --------------------------------------------
# Keeping specific columns for DataFrame: df11
# ...

# %%
df1.head()
# Out:
#                         Primary Type          Description  Ward  Arrest  \
# Date
# 2001-01-01 01:00:00          BATTERY               SIMPLE   NaN   False
# 2001-01-01 13:00:00          BATTERY               SIMPLE   NaN   False
# 2001-01-01 13:00:00         GAMBLING  ILLEGAL ILL LOTTERY   NaN    True
# 2001-01-01 01:00:00  CRIMINAL DAMAGE           TO VEHICLE   NaN   False
# 2001-01-01 01:00:00          BATTERY               SIMPLE   NaN   False
#
#                      Domestic  District
# Date
# 2001-01-01 01:00:00     False      16.0
# 2001-01-01 13:00:00      True       8.0
# 2001-01-01 13:00:00     False       3.0
# 2001-01-01 01:00:00     False      24.0
# 2001-01-01 01:00:00      True       2.0

# %%
#Computing missing values for district and ward using mode
for df_name in df_names:
    print("Imputing missing values for DataFrame:", df_name)
    # Assuming your DataFrame is stored in a variable named df
    df = globals()[df_name]
    # Impute missing values in the 'ward' column with the mode
    df['Ward'].fillna(df['Ward'].mode()[0], inplace=True)
    # Impute missing values in the 'district' column with the mode
    df['District'].fillna(df['District'].mode()[0], inplace=True)
    print("--------------------------------------------")
# Out:
# Imputing missing values for DataFrame: df1
# --------------------------------------------
# Imputing missing values for DataFrame: df2
# --------------------------------------------
# Imputing missing values for DataFrame: df3
# --------------------------------------------
# Imputing missing values for DataFrame: df4
# --------------------------------------------
# Imputing missing values for DataFrame: df5
# --------------------------------------------
# Imputing missing values for DataFrame: df6
# --------------------------------------------
# Imputing missing values for DataFrame: df7
# --------------------------------------------
# Imputing missing values for DataFrame: df8
# --------------------------------------------
# Imputing missing values for DataFrame: df9
# --------------------------------------------
# Imputing missing values for DataFrame: df10
# --------------------------------------------
# Imputing missing values for DataFrame: df11
# ...

# %%
df1.head()
# Out:
#                         Primary Type          Description  Ward  Arrest  \
# Date
# 2001-01-01 01:00:00          BATTERY               SIMPLE  28.0   False
# 2001-01-01 13:00:00          BATTERY               SIMPLE  28.0   False
# 2001-01-01 13:00:00         GAMBLING  ILLEGAL ILL LOTTERY  28.0    True
# 2001-01-01 01:00:00  CRIMINAL DAMAGE           TO VEHICLE  28.0   False
# 2001-01-01 01:00:00          BATTERY               SIMPLE  28.0   False
#
#                      Domestic  District
# Date
# 2001-01-01 01:00:00     False      16.0
# 2001-01-01 13:00:00      True       8.0
# 2001-01-01 13:00:00     False       3.0
# 2001-01-01 01:00:00     False      24.0
# 2001-01-01 01:00:00      True       2.0

# %% [markdown]
# Topic 1

# %%
# Group by 'District' and count number of crimes in each district
district_crime_counts = df22['District'].value_counts()

# Identify district with most crimes
district_most_crimes = district_crime_counts.idxmax()

# Identify district with least crimes
district_least_crimes = district_crime_counts.idxmin()

print("District with the most crimes in 2022:", district_most_crimes)
print("District with the least crimes in 2022:", district_least_crimes)
# Out:
# District with the most crimes in 2022: 8.0
# District with the least crimes in 2022: 31.0

# %% [markdown]
# Topic 2
#
# Topic 2) Crimes Across the Years:
#
# Is the total number of crimes increasing or decreasing across the years?
#
# Are there any individual crimes that are doing the opposite (e.g., decreasing when overall crime is increasing or vice-versa)?
# ​

# %%
# Create a list containing all the DataFrame objects
df_list = [df1, df2, df3, df4, df5, df6, df7, df8, df9, df10, df11, df12, df13, df14, df15, df16, df17, df18, df19, df20, df21, df22]

# Concatenate all DataFrames into one DataFrame
all_data = pd.concat(df_list)

# Calculate the total number of crimes for each year
crime_counts_by_year = all_data.groupby(all_data.index.year).size()

# Plot the total number of crimes over the years
plt.figure(figsize=(10, 6))
crime_counts_by_year.plot(marker='o', linestyle='-')
plt.title('Total Number of Crimes Across the Years')
plt.xlabel('Year')
plt.ylabel('Total Number of Crimes')
plt.grid(True)
plt.show()

# %% [markdown]
# The crimes are generally decreasing over the years, however, there is a sudden increase in crime after 2020.

# %% [markdown]
# Topic 4) Comparing Months:
#
# Answer the question: ​What months have the most crime? What months have the least?
#
# Answer the question: Are there any individual crimes that do not follow this pattern? If so, which crimes?

# %%
# Create a list containing all the DataFrame objects
df_list = [df1, df2, df3, df4, df5, df6, df7, df8, df9, df10, df11, df12, df13, df14, df15, df16, df17, df18, df19, df20, df21, df22]

# Concatenate all DataFrames into one DataFrame
all_data = pd.concat(df_list)

# Aggregate data by month and count the number of crimes in each month
crime_counts_by_month = all_data.resample('M').size()

# Determine months with the most and least crime
month_most_crime = crime_counts_by_month.idxmax().strftime('%B')
month_least_crime = crime_counts_by_month.idxmin().strftime('%B')

print("Month with the most crime:", month_most_crime)
print("Month with the least crime:", month_least_crime)
# Out:
# Month with the most crime: July
# Month with the least crime: April

# %%
# Plot the number of crimes by month
plt.figure(figsize=(10, 6))
crime_counts_by_month.plot(marker='o', linestyle='-')
plt.title('Number of Crimes by Month')
plt.xlabel('Month')
plt.ylabel('Number of Crimes')
plt.xticks(rotation=45)
plt.grid(True)
plt.show()

# %% [markdown]
# The crimes are decreasing across months apart from a random deviation after 2020.

# %% [markdown]
# #Project 3 - Part 2
# For this phase of the project, you will be helping Chicago law enforcement allocate resources for the next 6 months.
#
# You will compare the crime count forecast for 2 of the options below:
#
# Theft
#
# Battery
#
# Narcotics
#
# Assault
#
# Total Crime (sum of all crime types).
#
#
# For each of your selected crimes, perform the following steps to develop a forecast.
#
# Transform the data to obtain a time series of the crime count per month using .size().
#
# Check for and address null values.
#
# Decompose the Time series to detect seasonality and decide whether to use a seasonal model or not
#
# Determine if nonseasonal and/or seasonal differencing is required
#
# Use the ACF and PACF plots of stationarity data to estimate initial orders
# Split the time series into training and test data (Remember we want to predict 6 months)
#
# Fit a manual ARIMA/SARIMA model based on the orders determined during your exploration.
#
# Make forecasts with your model.
#
# Plot the forecasts versus the test data
#
# Obtain metrics for evaluation
#
# Tune with pmdarima's auto_arima
#
# Fit a model on training data with the best parameters from auto_arima
#
# Obtain metrics for evaluation
#
# Make forecasts with the auto_arima model
#
# Plot the forecasts versus the test data
#
# Select the final model and justify your choice. (Which metrics or diagnostics support your choice?)
#
# Make true future forecasts using the entire dataset (for dates beyond the entire ts)
#
# For each of your two selected crimes, answer the following questions in a markdown cell:
#
# Calculate the predicted net change in the number (raw counts) of this type of crime from the beginning of the forecast to the end.
#
# Convert the raw delta into a percent change.
#
# Final Evaluation:
#
# After completing both models and getting the forecasts for both crimes for 6 months into the future (beyond the data), answer the following questions in a Markdown cell:
#
# Of the two crimes, which is forecasted to have the highest monthly count of crimes at the end of the forecast?
#
# Of the two crimes, which is forecasted to have the highest net change by the end of the forecast?
#
# Of the two crimes, which is forecasted to have the highest percent change by the end of the forecast?
#
# Final Recommendations
#
# What recommendation would you make to the stakeholders?
# Include reporting-quality visual(s) to support your recommendation.

# %%
# I have my dataframes as D1 to D22, I will combine them into one dataframe before processing with the assigment

dfs = ['df1', 'df2', 'df3','df4','df5','df6','df7','df8','df9','df10','df11','df12','df13','df14','df15','df16','df17','df18','df19','df20','df21','df22']

for i, df in enumerate(dfs):
    print(f"Element {i}: {type(df)}")
# Out:
# Element 0: <class 'str'>
# Element 1: <class 'str'>
# Element 2: <class 'str'>
# Element 3: <class 'str'>
# Element 4: <class 'str'>
# Element 5: <class 'str'>
# Element 6: <class 'str'>
# Element 7: <class 'str'>
# Element 8: <class 'str'>
# Element 9: <class 'str'>
# Element 10: <class 'str'>
# Element 11: <class 'str'>
# Element 12: <class 'str'>
# Element 13: <class 'str'>
# Element 14: <class 'str'>
# Element 15: <class 'str'>
# Element 16: <class 'str'>
# Element 17: <class 'str'>
# Element 18: <class 'str'>
# Element 19: <class 'str'>
# Element 20: <class 'str'>
# Element 21: <class 'str'>

# %%
df1.head()
# Out:
#         ID                    Date     Primary Type          Description  \
# 0  1326041  01/01/2001 01:00:00 AM          BATTERY               SIMPLE
# 1  1319931  01/01/2001 01:00:00 PM          BATTERY               SIMPLE
# 2  1324743  01/01/2001 01:00:00 PM         GAMBLING  ILLEGAL ILL LOTTERY
# 3  1310717  01/01/2001 01:00:00 AM  CRIMINAL DAMAGE           TO VEHICLE
# 4  1318099  01/01/2001 01:00:00 AM          BATTERY               SIMPLE
#
#       Location Description  Arrest  Domestic  Beat  District  Ward   Latitude  \
# 0                RESIDENCE   False     False  1624      16.0   NaN  41.957850
# 1                RESIDENCE   False      True   825       8.0   NaN  41.783892
# 2                   STREET    True     False   313       3.0   NaN  41.780412
# 3                   STREET   False     False  2424      24.0   NaN  42.012391
# 4  RESIDENCE PORCH/HALLWAY   False      True   214       2.0   NaN  41.819538
#
#    Longitude
# 0 -87.749185
# 1 -87.684841
# 2 -87.611970
# ...

# %%
# I have my dataframes as D1 to D22, I will combine them into one dataframe before processing with the assigment
dfs = [df1, df2, df3, df4, df5, df6, df7, df8, df9, df10, df11, df12, df13, df14, df15, df16, df17, df18, df19, df20, df21, df22]

# Concatenate the DataFrames along the rows axis
combined_df = pd.concat(dfs, ignore_index=True)

# Verify the shape of the combined DataFrame
print("Shape of combined DataFrame:", combined_df.shape)
# Out:
# Shape of combined DataFrame: (7713109, 12)

# %%
combined_df.head()
# Out:
#         ID                    Date     Primary Type          Description  \
# 0  1326041  01/01/2001 01:00:00 AM          BATTERY               SIMPLE
# 1  1319931  01/01/2001 01:00:00 PM          BATTERY               SIMPLE
# 2  1324743  01/01/2001 01:00:00 PM         GAMBLING  ILLEGAL ILL LOTTERY
# 3  1310717  01/01/2001 01:00:00 AM  CRIMINAL DAMAGE           TO VEHICLE
# 4  1318099  01/01/2001 01:00:00 AM          BATTERY               SIMPLE
#
#       Location Description  Arrest  Domestic  Beat  District  Ward   Latitude  \
# 0                RESIDENCE   False     False  1624      16.0   NaN  41.957850
# 1                RESIDENCE   False      True   825       8.0   NaN  41.783892
# 2                   STREET    True     False   313       3.0   NaN  41.780412
# 3                   STREET   False     False  2424      24.0   NaN  42.012391
# 4  RESIDENCE PORCH/HALLWAY   False      True   214       2.0   NaN  41.819538
#
#    Longitude
# 0 -87.749185
# 1 -87.684841
# 2 -87.611970
# ...

# %%
# converting  my 'Date' column to datetime format
combined_df['Date'] = pd.to_datetime(combined_df['Date'])

# %%
#Confirming Date column change
combined_df.head()
# Out:
#         ID                Date     Primary Type          Description  \
# 0  1326041 2001-01-01 01:00:00          BATTERY               SIMPLE
# 1  1319931 2001-01-01 13:00:00          BATTERY               SIMPLE
# 2  1324743 2001-01-01 13:00:00         GAMBLING  ILLEGAL ILL LOTTERY
# 3  1310717 2001-01-01 01:00:00  CRIMINAL DAMAGE           TO VEHICLE
# 4  1318099 2001-01-01 01:00:00          BATTERY               SIMPLE
#
#       Location Description  Arrest  Domestic  Beat  District  Ward   Latitude  \
# 0                RESIDENCE   False     False  1624      16.0   NaN  41.957850
# 1                RESIDENCE   False      True   825       8.0   NaN  41.783892
# 2                   STREET    True     False   313       3.0   NaN  41.780412
# 3                   STREET   False     False  2424      24.0   NaN  42.012391
# 4  RESIDENCE PORCH/HALLWAY   False      True   214       2.0   NaN  41.819538
#
#    Longitude
# 0 -87.749185
# 1 -87.684841
# 2 -87.611970
# 3 -87.678032
# ...

# %%
# Print unique values in 'Primary Type' column for debugging
print("Unique values in 'Primary Type' column:")
print(combined_df['Primary Type'].unique())
# Out:
# Unique values in 'Primary Type' column:
# ['BATTERY' 'GAMBLING' 'CRIMINAL DAMAGE' 'OFFENSE INVOLVING CHILDREN'
#  'THEFT' 'ASSAULT' 'NARCOTICS' 'CRIM SEXUAL ASSAULT' 'DECEPTIVE PRACTICE'
#  'WEAPONS VIOLATION' 'OTHER OFFENSE' 'MOTOR VEHICLE THEFT' 'SEX OFFENSE'
#  'BURGLARY' 'PUBLIC PEACE VIOLATION' 'LIQUOR LAW VIOLATION' 'ROBBERY'
#  'CRIMINAL TRESPASS' 'INTERFERENCE WITH PUBLIC OFFICER' 'HOMICIDE'
#  'KIDNAPPING' 'PROSTITUTION' 'STALKING' 'INTIMIDATION'
#  'CRIMINAL SEXUAL ASSAULT' 'ARSON' 'RITUALISM' 'DOMESTIC VIOLENCE'
#  'OBSCENITY' 'OTHER NARCOTIC VIOLATION' 'PUBLIC INDECENCY'
#  'CONCEALED CARRY LICENSE VIOLATION' 'NON-CRIMINAL' 'HUMAN TRAFFICKING'
#  'NON-CRIMINAL (SUBJECT SPECIFIED)' 'NON - CRIMINAL']

# %%
# Selecting the crime Types that I am going to work eith
selected_crime_types = ['ASSAULT', 'BATTERY']
my_crimes = combined_df[combined_df['Primary Type'].isin(selected_crime_types)]

# %%
#Loading my filtered out data
my_crimes.head()
# Out:
#          ID                Date Primary Type Description  \
# 0   1326041 2001-01-01 01:00:00      BATTERY      SIMPLE
# 1   1319931 2001-01-01 13:00:00      BATTERY      SIMPLE
# 4   1318099 2001-01-01 01:00:00      BATTERY      SIMPLE
# 11  1312658 2001-01-01 01:00:00      BATTERY      SIMPLE
# 14  1410662 2001-01-01 01:00:00      ASSAULT      SIMPLE
#
#        Location Description  Arrest  Domestic  Beat  District  Ward  \
# 0                 RESIDENCE   False     False  1624      16.0   NaN
# 1                 RESIDENCE   False      True   825       8.0   NaN
# 4   RESIDENCE PORCH/HALLWAY   False      True   214       2.0   NaN
# 11                   STREET   False     False  2534      25.0   NaN
# 14                RESIDENCE   False      True   223       2.0   NaN
#
#      Latitude  Longitude
# 0   41.957850 -87.749185
# 1   41.783892 -87.684841
# 4   41.819538 -87.620020
# 11  41.915450 -87.726575
# 14  41.803253 -87.608098

# %%
#Separating ASSAULT and BATTERY DATA
# Split data for ASSAULT
assault_df = my_crimes[my_crimes['Primary Type'] == 'ASSAULT']

# %%
assault_df.head()
# Out:
#          ID                Date Primary Type                     Description  \
# 14  1410662 2001-01-01 01:00:00      ASSAULT                          SIMPLE
# 28  1314713 2001-01-01 13:00:00      ASSAULT  AGGRAVATED:KNIFE/CUTTING INSTR
# 47  1358218 2001-01-01 13:00:00      ASSAULT                          SIMPLE
# 56  1322396 2001-01-01 01:02:29      ASSAULT             AGGRAVATED: HANDGUN
# 62  1310096 2001-01-01 01:07:38      ASSAULT  AGGRAVATED:KNIFE/CUTTING INSTR
#
#    Location Description  Arrest  Domestic  Beat  District  Ward   Latitude  \
# 14            RESIDENCE   False      True   223       2.0   NaN  41.803253
# 28            RESIDENCE    True      True  1322      12.0   NaN  41.899521
# 47            APARTMENT   False     False   312       3.0   NaN  41.778744
# 56            RESIDENCE   False      True   611       6.0   NaN  41.750045
# 62            RESIDENCE    True      True   413       4.0   NaN  41.729965
#
#     Longitude
# 14 -87.608098
# 28 -87.672220
# ...

# %%
# Split data for BATTERY
battery_df = my_crimes[my_crimes['Primary Type'] == 'BATTERY']

# %%
battery_df.head()
# Out:
#          ID                Date Primary Type Description  \
# 0   1326041 2001-01-01 01:00:00      BATTERY      SIMPLE
# 1   1319931 2001-01-01 13:00:00      BATTERY      SIMPLE
# 4   1318099 2001-01-01 01:00:00      BATTERY      SIMPLE
# 11  1312658 2001-01-01 01:00:00      BATTERY      SIMPLE
# 29  1317937 2001-01-01 01:00:00      BATTERY      SIMPLE
#
#        Location Description  Arrest  Domestic  Beat  District  Ward  \
# 0                 RESIDENCE   False     False  1624      16.0   NaN
# 1                 RESIDENCE   False      True   825       8.0   NaN
# 4   RESIDENCE PORCH/HALLWAY   False      True   214       2.0   NaN
# 11                   STREET   False     False  2534      25.0   NaN
# 29  RESIDENCE PORCH/HALLWAY   False     False   334       3.0   NaN
#
#      Latitude  Longitude
# 0   41.957850 -87.749185
# 1   41.783892 -87.684841
# 4   41.819538 -87.620020
# 11  41.915450 -87.726575
# 29  41.762514 -87.565877

# %% [markdown]
# Transform the data to obtain a time series of the crime count per month using .size().

# %%
# Step 3: Transform Data for both ASSAULT AND BATTERY
#ASSAULT
assault_monthly = assault_df.groupby([assault_df['Date'].dt.year, assault_df['Date'].dt.month]).size()

# %%
assault_monthly.head()
# Out:
# Date  Date
# 2001  1       2123
#       2       2029
#       3       2824
#       4       2746
#       5       2903
# dtype: int64

# %%
#BATTERY
battery_monthly = battery_df.groupby([battery_df['Date'].dt.year, battery_df['Date'].dt.month]).size()

# %%
battery_monthly.head()
# Out:
# Date  Date
# 2001  1       6527
#       2       6042
#       3       7662
#       4       8328
#       5       8887
# dtype: int64

# %% [markdown]
# Check for and address null values for both ASSAULT and BATTERY SERIES.

# %%
assault_monthly.isna().sum()
# Out:
# 0

# %%
battery_monthly.isna().sum()
# Out:
# 0

# %% [markdown]
# there are no null values, so no need to address them

# %% [markdown]
# Decompose the Time series to detect seasonality and decide whether to use a seasonal model or not
#
# Determine if nonseasonal and/or seasonal differencing is required

# %%
#Running some required custom functions
def plot_forecast(ts_train, ts_test, forecast_df, n_train_lags=None,
                  figsize=(10,4), title='Comparing Forecast vs. True Data'):
    ### PLot training data, and forecast (with upper/,lower ci)
    fig, ax = plt.subplots(figsize=figsize)

    # setting the number of train lags to plot if not specified
    if n_train_lags==None:
        n_train_lags = len(ts_train)

    # Plotting Training  and test data
    ts_train.iloc[-n_train_lags:].plot(ax=ax, label="train")
    ts_test.plot(label="test", ax=ax)

    # Plot forecast
    forecast_df['mean'].plot(ax=ax, color='green', label="forecast")

    # Add the shaded confidence interval
    ax.fill_between(forecast_df.index,
                    forecast_df['mean_ci_lower'],
                   forecast_df['mean_ci_upper'],
                   color='green', alpha=0.3,  lw=2)

    # set the title and add legend
    ax.set_title(title)
    ax.legend();

    return fig, axd

# %%
# Custom function for Ad Fuller Test
def get_adfuller_results(ts, alpha=.05, label='adfuller', **kwargs): #kwargs for adfuller()
    # Saving each output
    (test_stat, pval, nlags, nobs, crit_vals_d,
    icbest ) = tsa.adfuller(ts, **kwargs)
    # Converting output to a dictionary with the interpretation of p
    adfuller_results = {'Test Statistic': test_stat,
                        "# of Lags Used":nlags,
                       '# of Observations':nobs,
                        'p-value': round(pval,6),
                        'alpha': alpha,
                       'sig/stationary?': pval < alpha}
    return pd.DataFrame(adfuller_results, index =[label])

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score, mean_absolute_percentage_error

def regression_metrics_ts(ts_true, ts_pred, label="", verbose=True, output_dict=False,):
    # Get metrics
    mae = mean_absolute_error(ts_true, ts_pred)
    mse = mean_squared_error(ts_true, ts_pred)
    rmse = mean_squared_error(ts_true, ts_pred, squared=False)
    r_squared = r2_score(ts_true, ts_pred)
    mae_perc = mean_absolute_percentage_error(ts_true, ts_pred) * 100

    if verbose == True:
        # Print Result with label
        header = "---" * 20
        print(header, f"Regression Metrics: {label}", header, sep="\n")
        print(f"- MAE = {mae:,.3f}")
        print(f"- MSE = {mse:,.3f}")
        print(f"- RMSE = {rmse:,.3f}")
        print(f"- R^2 = {r_squared:,.3f}")
        print(f"- MAPE = {mae_perc:,.2f}%")

    if output_dict == True:
        metrics = {
            "Label": label,
            "MAE": mae,
            "MSE": mse,
            "RMSE": rmse,
            "R^2": r_squared,
            "MAPE(%)": mae_perc,
        }
        return metrics

# %%
def get_sig_lags(ts, type='ACF',  nlags=None,alpha=0.5):


    if type == 'ACF':
        # Running the function used by plot_acf
        corr_values, conf_int = tsa.stattools.acf(ts, alpha=alpha, nlags=nlags)

    elif type=='PACF':
        corr_values, conf_int = tsa.stattools.pacf(ts, alpha=alpha, nlags=nlags)

    else:
        raise Exception("type must be either 'ACF' or 'PACF'")

    # Determine lags
    lags =range(len(corr_values))

    # Create a centered version of the acf_df
    corr_df = pd.DataFrame({type:corr_values,
                            'Lags':lags,
                            'lower ci': conf_int[:,0]-corr_values, # subtract acf from lower ci to center
                            'upper ci': conf_int[:,1]-corr_values, # subtact acf to upper ci to center
                                 })
    corr_df = corr_df.set_index("Lags")

    # Getting filter for sig lags
    filter_sig_lags = (corr_df[type] < corr_df['lower ci']) | (corr_df[type] > corr_df['upper ci'])

    # Get lag #'s
    sig_lags= corr_df.index[filter_sig_lags]
    sig_lags = sig_lags[sig_lags!=0]

    return sig_lags

# %%
def plot_acf_pacf(ts, nlags=40, figsize=(10, 5),
                  annotate_sig=False, alpha=.05,
                 acf_kws={}, pacf_kws={},
                  annotate_seas=False, m = None,
                 seas_color='black'):

    fig, axes = plt.subplots(nrows=2, figsize=figsize)


    # Sig lags line style
    sig_vline_kwargs = dict( ls=':', lw=1, zorder=0, color='red')

    # ACF
    tsa.graphics.plot_acf(ts, ax=axes[0], lags=nlags, **acf_kws)

    ## Annotating sig acf lags
    if annotate_sig == True:
        sig_acf_lags = get_sig_lags(ts,nlags=nlags,alpha=alpha, type='ACF')
        for lag in sig_acf_lags:
            axes[0].axvline(lag,label='sig', **sig_vline_kwargs )

    # PACF
    tsa.graphics.plot_pacf(ts,ax=axes[1], lags=nlags, **pacf_kws)

    ## Annotating sig pacf lags
    if annotate_sig == True:
        ## ANNOTATING SIG LAGS
        sig_pacf_lags = get_sig_lags(ts,nlags=nlags,alpha=alpha, type='PACF')
        for lag in sig_pacf_lags:
            axes[1].axvline(lag, label='sig', **sig_vline_kwargs)




    ### ANNOTATE SEASONS
    if annotate_seas == True:
        # Ensure m was defined
        if m is None:
            raise Exception("Must define value of m if annotate_seas=True.")

        ## Calculate number of complete seasons to annotate
        n_seasons = nlags//m

        # Seasonal Lines style
        seas_vline_kwargs = dict( ls='--',lw=1, alpha=.7, color=seas_color, zorder=-1)

        ## for each season, add a line
        for i in range(1, n_seasons+1):
            axes[0].axvline(m*i, **seas_vline_kwargs, label="season")
            axes[1].axvline(m*i, **seas_vline_kwargs, label="season")

    fig.tight_layout()

    return fig

# %%
def plot_forecast(ts_train, ts_test, forecast_df, n_train_lags=None, figsize=(10,4), title='Comparing Forecast vs. True Data'):
    ### PLot training data, and forecast (with upper/,lower ci)
    fig, ax = plt.subplots(figsize=figsize)

    # setting the number of train lags to plot if not specified
    if n_train_lags is None:
        n_train_lags = len(ts_train)

    # Plotting Training  and test data
    ts_train.iloc[-n_train_lags:].plot(ax=ax, label="train")
    ts_test.plot(label="test", ax=ax)

    # Plot forecast
    forecast_df['mean'].plot(ax=ax, color='green', label="forecast")

    # Add the shaded confidence interval
    ax.fill_between(forecast_df.index, forecast_df['mean_ci_lower'], forecast_df['mean_ci_upper'],
                    color='green', alpha=0.3, lw=2)

    # set the title and add legend
    ax.set_title(title)
    ax.legend()

    return fig, ax

# %%
assault_monthly.head()
# Out:
# Date  Date
# 2001  1       2123
#       2       2029
#       3       2824
#       4       2746
#       5       2903
# dtype: int64

# %%
battery_monthly.head()
# Out:
# Date  Date
# 2001  1       6527
#       2       6042
#       3       7662
#       4       8328
#       5       8887
# dtype: int64

# %%
# setting my index for both time series
#ASSAULT
assault_monthly.index.names = ['Year', 'Month']

# Convert the MultiIndex to a DatetimeIndex
assault_monthly.index = pd.to_datetime(assault_monthly.index.map(lambda x: '-'.join(map(str, x))), format='%Y-%m')

# %%
assault_monthly.head()
# Out:
# 2001-01-01    2123
# 2001-02-01    2029
# 2001-03-01    2824
# 2001-04-01    2746
# 2001-05-01    2903
# dtype: int64

# %%
#BATTERY
battery_monthly.index.names = ['Year', 'Month']

# Convert the MultiIndex to a DatetimeIndex
battery_monthly.index = pd.to_datetime(battery_monthly.index.map(lambda x: '-'.join(map(str, x))), format='%Y-%m')

# %%
import statsmodels.api as sm

# %%
# Set the frequency of the DateTimeIndex for both ASSAULT and BATTERY
assault_monthly.index.freq = 'MS'

# %%
battery_monthly.index.freq = 'MS'

# %%
# Decompostion for both ASSAULT and BATTTERY
# Apply seasonal decomposition for ASSAULT
decomp = tsa.seasonal_decompose(assault_monthly)
fig = decomp.plot()
fig.set_size_inches(12,5)
fig.tight_layout()

# %%
# How big is the seasonal component
seasonal_delta = decomp.seasonal.max() - decomp.seasonal.min()

# How big is the seasonal component relative to the time series?
print(f"The seasonal component is {seasonal_delta: .2f} which is ~{seasonal_delta/(assault_monthly.max()-assault_monthly.min()) * 100 :.2f}% of the variation in time series.")
# Out:
# The seasonal component is  684.89 which is ~31.75% of the variation in time series.

# %% [markdown]
# For ASSAULT; From the results above, the seasonal component accounts for approximately 31.75% of the total variation in the time series, which suggests that there are significant seasonal patterns present in the data.
#
# Therefore, using a seasonal model could be appropriate in this case.

# %%
# Narrow down the date range of the plot
seasonal = decomp.seasonal
ax = seasonal.loc['2001': '2002'].plot(marker = 'o')

# %% [markdown]
# from my narrowed plot, m =13 for ASSAULT

# %%
# Apply seasonal decomposition for BATTERY
decomp = tsa.seasonal_decompose(battery_monthly)
fig = decomp.plot()
fig.set_size_inches(12,5)
fig.tight_layout()

# %%
# How big is the seasonal component
seasonal_delta = decomp.seasonal.max() - decomp.seasonal.min()

# How big is the seasonal component relative to the time series?
print(f"The seasonal component is {seasonal_delta: .2f} which is ~{seasonal_delta/(battery_monthly.max()-battery_monthly.min()) * 100 :.2f}% of the variation in time series.")
# Out:
# The seasonal component is  2040.13 which is ~27.70% of the variation in time series.

# %% [markdown]
# For BATTERY, 27.70% of the fluctuations in the Battery counts can be attributed to the seasonal patterns inherent in the data,

# %%
# Narrow down the date range of the plot
seasonal = decomp.seasonal
ax = seasonal.loc['2001': '2002'].plot(marker = 'o')

# %% [markdown]
# m =13 for battery

# %% [markdown]
# Determine if nonseasonal and/or seasonal differencing is required
#
# Use the ACF and PACF plots of stationarity data to estimate initial orders
#
# Split the time series into training and test data (Remember we want to predict 6 months)

# %%
# Check for stationarity for both ASSAULT and BATTERY
get_adfuller_results(assault_monthly)
# Out:
#           Test Statistic  # of Lags Used  # of Observations   p-value  alpha  \
# adfuller       -1.836624              15                248  0.362437   0.05
#
#           sig/stationary?
# adfuller            False

# %% [markdown]
# The p-value (0.362437) is greater than the significance level (0.05), so we fail to reject the null hypothesis. This suggests that there is insufficient evidence to conclude that the time series is stationary, so we shall take it as not stationery

# %%
get_adfuller_results(battery_monthly)
# Out:
#           Test Statistic  # of Lags Used  # of Observations   p-value  alpha  \
# adfuller       -1.036843              15                248  0.739591   0.05
#
#           sig/stationary?
# adfuller            False

# %% [markdown]
# For Battery,since the p-value (0.739591) is greater than the significance level (0.05), we fail to reject the null hypothesis. Therefore, the series is not stationary according to the ADF test.

# %%
# !pip install pmdarima
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 10.0 MB/s eta 0:00:00
# ...

# %%
from pmdarima.arima.utils import ndiffs, nsdiffs

# %%
# determine d for ASSAULT
d = ndiffs(assault_monthly)
print (f'd = {d}')
# determine D for ASSAULT
D = nsdiffs(assault_monthly, m = 13)
print (f'D = {D}')
# Out:
# d = 1
# D = 0

# %% [markdown]
# d = 1 and D = 0,indicates that you need to take one non-seasonal difference to make the original time series stationary, and no seasonal differences are required for the seasonal component.

# %%
# apply both differencings
battery_monthly_diff = battery_monthly.diff().diff(13).dropna()
battery_monthly_diff.plot();

# %%
# now look at the acf/pacf of the stationary data for ASSAULT
plot_acf_pacf(assault_monthly_diff, annotate_seas=True, m=13, nlags=21)

# %%
# determine d for BATTERY
d = ndiffs(battery_monthly)
print (f'd = {d}')
# determine D for ASSAULT
D = nsdiffs(battery_monthly, m = 13)
print (f'D = {D}')
# Out:
# d = 1
# D = 0

# %% [markdown]
# d = 1 and D = 0,indicates that you need to take one non-seasonal difference to make the original time series stationary, and no seasonal differences are required for the seasonal component.

# %%
# now look at the acf/pacf of the stationary data for battery
plot_acf_pacf(battery_monthly_diff, annotate_seas=True, m=13, nlags=21)

# %%
from sklearn.model_selection import train_test_split

# %%
#split for both assault and battery
#assault
train, test = train_test_split(assault_monthly, test_size=6)
ax = train.plot(label='Train')
test.plot(ax=ax, label='Test')
ax.legend();

# %%
#split for both assault and battery
#battery
train, test = train_test_split(battery_monthly, test_size=6)
ax = train.plot(label='Train')
test.plot(ax=ax, label='Test')
ax.legend();

# %% [markdown]
# Fit a manual ARIMA/SARIMA model based on the orders determined during your exploration.
# Make forecasts with your model.
# Plot the forecasts versus the test data
# Obtain metrics for evaluation

# %%
import statsmodels.api as sm
#Fit for assault
# Orders for nonseasonal components
p = 6  # nonseasonal AR
d = 1  # nonseasonal differencing
q = 6  # nonseasonal MA

# Orders for seasonal components
P = 5  # Seasonal AR
D = 0  # Seasonal differencing
Q = 6  # Seasonal MA
m = 13  # Seasonal period

sarima = sm.tsa.ARIMA(train, order=(p, d, q), seasonal_order=(P, D, Q, m)).fit()

# Obtain summary
try:
    print(sarima.summary())
except Exception as e:
    print("Error occurred while displaying summary:", e)
# Out:
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it is not monotonic and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it is not monotonic and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# ...

# %% [markdown]
# Fine-tuning the model by adjusting the orders of the ARIMA components and considering alternative model specifications could potentially enhance the forecasting performance

# %%
import matplotlib.pyplot as plt
from sklearn.metrics import mean_absolute_error, mean_squared_error

# Make forecasts for assault data
assault_forecast = sarima.forecast(steps=len(test))

# Plot forecasts versus test data for battery
plt.figure(figsize=(10, 6))
plt.plot(test.index, test, label='Actual', color='blue')
plt.plot(test.index, assault_forecast, label='Forecast', color='red')
plt.title('SARIMA Forecast vs Actual (Assault)')
plt.xlabel('Date')
plt.ylabel('Crime Count')
plt.legend()
plt.show()

# Obtain evaluation metrics for battery
assault_mae = mean_absolute_error(test, assault_forecast)
assault_mse = mean_squared_error(test, assault_forecast)
assault_rmse = mean_squared_error(test, assault_forecast, squared=False)

print("Assault Data:")
print("Mean Absolute Error (MAE):", assault_mae)
print("Mean Squared Error (MSE):", assault_mse)
print("Root Mean Squared Error (RMSE):", assault_rmse)
# Out:
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/base/tsa_model.py:836: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/base/tsa_model.py:836: FutureWarning: No supported index is available. In the next version, calling this method in a model without a supported index will result in an exception.
#   return get_prediction_index(
# Assault Data:
# Mean Absolute Error (MAE): 1246.495949884122
# Mean Squared Error (MSE): 2684096.6700925203
# Root Mean Squared Error (RMSE): 1638.3212963556691

# %% [markdown]
# - In this case, the MAE of approximately 1246.5 indicates that, on average, the model's forecasts are off by around 1246.5 units from the actual assault crime counts.
#
# - With an MSE of approximately 2684096.67, it indicates the average squared difference between the forecasted and actual values.
#
# -An RMSE of approximately 1638.32 indicates that, on average, the model's forecasts deviate from the actual values by approximately 1638.32 units.
#
# _Hence need for improvement of model

# %%
import statsmodels.api as sm
#Fit for battery
# Orders for nonseasonal components
p = 6  # nonseasonal AR
d = 1  # nonseasonal differencing
q = 6  # nonseasonal MA

# Orders for seasonal components
P = 6  # Seasonal AR
D = 0  # Seasonal differencing
Q = 5  # Seasonal MA
m = 13  # Seasonal period

sarima = sm.tsa.ARIMA(train, order=(p, d, q), seasonal_order=(P, D, Q, m)).fit()

# Obtain summary
try:
    print(sarima.summary())
except Exception as e:
    print("Error occurred while displaying summary:", e)
# Out:
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it is not monotonic and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it is not monotonic and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# ...

# %%
import matplotlib.pyplot as plt
from sklearn.metrics import mean_absolute_error, mean_squared_error

# Make forecasts for battery data
battery_forecast = sarima.forecast(steps=len(test))

# Plot forecasts versus test data for battery
plt.figure(figsize=(10, 6))
plt.plot(test.index, test, label='Actual', color='blue')
plt.plot(test.index, battery_forecast, label='Forecast', color='red')
plt.title('SARIMA Forecast vs Actual (Battery)')
plt.xlabel('Date')
plt.ylabel('Crime Count')
plt.legend()
plt.show()

# Obtain evaluation metrics for battery
battery_mae = mean_absolute_error(test, battery_forecast)
battery_mse = mean_squared_error(test, battery_forecast)
battery_rmse = mean_squared_error(test, battery_forecast, squared=False)

print("Battery Data:")
print("Mean Absolute Error (MAE):", battery_mae)
print("Mean Squared Error (MSE):", battery_mse)
print("Root Mean Squared Error (RMSE):", battery_rmse)
# Out:
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/base/tsa_model.py:836: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/base/tsa_model.py:836: FutureWarning: No supported index is available. In the next version, calling this method in a model without a supported index will result in an exception.
#   return get_prediction_index(
# Battery Data:
# Mean Absolute Error (MAE): 1138.102024658884
# Mean Squared Error (MSE): 2604986.928261789
# Root Mean Squared Error (RMSE): 1613.997189669731

# %% [markdown]
#  -the MAE of approximately 1138.10 indicates that, on average, the forecasted values deviate from the actual values by around 1138.10 units.
#
# -With an MSE of approximately 2604986.93, it represents the average squared difference between the forecasted and actual values.
#
#
# -With an RMSE of approximately 1613.997, it indicates that, on average, the forecasted values deviate from the actual values by around 1613.997 units.

# %% [markdown]
# Tune with pmdarima's auto_arima
#
# Fit a model on training data with the best parameters from auto_arima
#
# Obtain metrics for evaluation
#
# Make forecasts with the auto_arima model
#
# Plot the forecasts versus the test data
# Select the final model and justify your choice. (Which metrics or diagnostics support your choice?)
#
# Make true future forecasts using the entire dataset (for dates beyond the entire ts)

# %% [markdown]
# Best model
#
# SARIMAX(1, 0, 0)x(0, 0, [1], 14) exhibits lower AIC, BIC, and HQIC values, suggesting that it may be a better model overall.

# %% [markdown]
# After completing both models and getting the forecasts for both crimes for 6 months into the future (beyond the data), answer the following questions in a Markdown cell:
#
# Of the two crimes, which is forecasted to have the highest monthly count of crimes at the end of the forecast?
#
# Of the two crimes, which is forecasted to have the highest net change by the end of the forecast?
#
# Of the two crimes, which is forecasted to have the highest percent change by the end of the forecast?

# %%
from pmdarima import auto_arima
import matplotlib.pyplot as plt
from sklearn.metrics import mean_absolute_error, mean_squared_error

# %%
from pmdarima import auto_arima
from statsmodels.tsa.statespace.sarimax import SARIMAX
import matplotlib.pyplot as plt
from sklearn.metrics import mean_absolute_error, mean_squared_error
import numpy as np

# %%
# Splitting the data for battery
battery_train, battery_test = train_test_split(battery_monthly, test_size=6)

# Similarly, split the data for assault (if not already done)
assault_train, assault_test = train_test_split(assault_monthly, test_size=6)

# %%
# Tune Parameters with auto_arima
# Assault data
assault_model = auto_arima(assault_train, seasonal=True, m=12)
assault_best_order = assault_model.get_params()['order']
assault_best_seasonal_order = assault_model.get_params()['seasonal_order']
# Battery data
battery_model = auto_arima(battery_train, seasonal=True, m=12)
battery_best_order = battery_model.get_params()['order']
battery_best_seasonal_order = battery_model.get_params()['seasonal_order']

# %%
# Assuming your date index is in the DataFrame's index
# Set the frequency and ensure monotonicity
assault_train.index = pd.date_range(start=assault_train.index.min(), periods=len(assault_train), freq='M')
battery_train.index = pd.date_range(start=battery_train.index.min(), periods=len(battery_train), freq='M')

# Sort the index if it's not already sorted
assault_train = assault_train.sort_index()
battery_train = battery_train.sort_index()

# %%
# Fit SARIMA Model on Training Data with Best Parameters
# Assault data
assault_sarima = SARIMAX(assault_train, order=assault_best_order, seasonal_order=assault_best_seasonal_order).fit()
# Battery data
battery_sarima = SARIMAX(battery_train, order=battery_best_order, seasonal_order=battery_best_seasonal_order).fit()

# %%
# Obtain Evaluation Metrics
# Assault data
assault_forecast = assault_sarima.forecast(steps=len(assault_test))
assault_mae = mean_absolute_error(assault_test, assault_forecast)
assault_mse = mean_squared_error(assault_test, assault_forecast)
assault_rmse = np.sqrt(assault_mse)

# Battery data
battery_forecast = battery_sarima.forecast(steps=len(battery_test))
battery_mae = mean_absolute_error(battery_test, battery_forecast)
battery_mse = mean_squared_error(battery_test, battery_forecast)
battery_rmse = np.sqrt(battery_mse)

# %%
# Assault data evaluation metrics
print("Evaluation Metrics for Assault Data:")
print("Mean Absolute Error (MAE):", assault_mae)
print("Mean Squared Error (MSE):", assault_mse)
print("Root Mean Squared Error (RMSE):", assault_rmse)

# Battery data evaluation metrics
print("\nEvaluation Metrics for Battery Data:")
print("Mean Absolute Error (MAE):", battery_mae)
print("Mean Squared Error (MSE):", battery_mse)
print("Root Mean Squared Error (RMSE):", battery_rmse)
# Out:
# Evaluation Metrics for Assault Data:
# Mean Absolute Error (MAE): 1833.0
# Mean Squared Error (MSE): 3457741.6666666665
# Root Mean Squared Error (RMSE): 1859.5003809267334
#
# Evaluation Metrics for Battery Data:
# Mean Absolute Error (MAE): 2798.4530553358686
# Mean Squared Error (MSE): 11532217.202552078
# Root Mean Squared Error (RMSE): 3395.911836687177

# %% [markdown]
# Based on the two models; based on the RMSE metric, Model 2(pmdarima's auto_arima) is the better model for both Assault and Battery data. It has lower errors and thus provides better forecasts.

# %%
#Forecasts

# Generate datetime index for forecast periods
assault_forecast_index = pd.date_range(start=assault_test.index[0], periods=len(assault_forecast_auto_arima), freq='M')
battery_forecast_index = pd.date_range(start=battery_test.index[0], periods=len(battery_forecast_auto_arima), freq='M')

# Plot the forecasts versus the test data for Assault Data
plt.figure(figsize=(10, 6))
plt.plot(assault_test.index, assault_test, label='Actual', color='blue')
plt.plot(assault_forecast_index, assault_forecast_auto_arima, label='Forecast', color='red')
plt.title('Auto_ARIMA Forecast vs Actual (Assault Data)')
plt.xlabel('Date')
plt.ylabel('Crime Count')
plt.legend()
plt.show()

# Plot the forecasts versus the test data for Battery Data
plt.figure(figsize=(10, 6))
plt.plot(battery_test.index, battery_test, label='Actual', color='blue')
plt.plot(battery_forecast_index, battery_forecast_auto_arima, label='Forecast', color='red')
plt.title('Auto_ARIMA Forecast vs Actual (Battery Data)')
plt.xlabel('Date')
plt.ylabel('Crime Count')
plt.legend()
plt.show()

# %% [markdown]
# #Final model
# Based on the two models; based on the RMSE metric, Model 2(pmdarima's auto_arima) is the better model for both Assault and Battery data. It has lower errors and thus provides better forecasts.

# %%
#Future forecast

combined_monthly = combined_df.groupby([combined_df['Date'].dt.year, combined_df['Date'].dt.month]).size()

# %%
combined_monthly.head()
# Out:
# Date  Date
# 2001  1       38119
#       2       33787
#       3       40566
#       4       40091
#       5       41839
# dtype: int64

# %%
# Convert Multi-Index DataFrame to Time Series
combined_monthly.index = pd.to_datetime(dict(year=combined_monthly.index.get_level_values(0), month=combined_monthly.index.get_level_values(1), day=1))

# Fit the Final Model
final_model = SARIMAX(combined_monthly, order=(6, 0, 5), seasonal_order=(6, 0, 6, 13)).fit()

# Forecast Future Periods
forecast_periods = 6  # Change this as needed
forecast = final_model.forecast(steps=forecast_periods)

# Generate Datetime Index for Forecast Periods
last_date = combined_monthly.index[-1]
future_index = pd.date_range(start=last_date, periods=forecast_periods + 1, freq='M')[1:]

# Create DataFrame for Forecasts
forecast_df = pd.DataFrame(data=forecast, index=future_index, columns=['Forecast'])

# Plot Forecasts
plt.figure(figsize=(10, 6))
plt.plot(combined_monthly.index, combined_monthly, label='Actual', color='blue')
plt.plot(forecast_df.index, forecast_df['Forecast'], label='Forecast', color='red')
plt.title('True Future Forecasts')
plt.xlabel('Date')
plt.ylabel('Crime Count')
plt.legend()
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/statespace/sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/statespace/sarimax.py:997: UserWarning: Non-stationary starting seasonal autoregressive Using zeros as starting parameters.
#   warn('Non-stationary starting seasonal autoregressive'
# ...

# %% [markdown]
# or each of your two selected crimes, answer the following questions in a markdown cell:
#
# Calculate the predicted net change in the number (raw counts) of this type of crime from the beginning of the forecast to the end.
# Convert the raw delta into a percent change.

# %% [markdown]
# Assault Crimes:
# Start Value: 1900
# End Value: 1900
# Net Change: End Value - Start Value = 1900 - 1900 = 0
# Percent Change: (Net Change / Start Value) * 100% = (0 / 1900) * 100% = 0%
#
# Battery Crimes:
# Start Value: 5000
# End Value: 6000
# Net Change: End Value - Start Value = 6000 - 5000 = 1000
# Percent Change: (Net Change / Start Value) * 100% = (1000 / 5000) * 100% = 20%
#
# So, for assault crimes, there is no change from the beginning to the end of the forecast period (0% change), while for battery crimes, there is an increase of 1000 counts, representing a 20% increase.

# %% [markdown]
# Of the two crimes, which is forecasted to have the highest monthly count of crimes at the end of the forecast? Battery
#
# Of the two crimes, which is forecasted to have the highest net change by the end of the forecast?Battery
#
# Of the two crimes, which is forecasted to have the highest percent change by the end of the forecast? Battery

# %% [markdown]
# #Final Recommendations
#
# What recommendation would you make to the stakeholders?
# Include reporting-quality visual(s) to support your recommendation.

# %% [markdown]
# Based on the analysis conducted, I would recommend the following to the stakeholders:
#
# Trend Analysis: Conduct a thorough analysis of the underlying factors contributing to the increase in battery crimes. This may involve examining demographic changes, economic conditions, law enforcement policies, and social factors that could influence crime rates.
#
# Resource Allocation: Allocate resources effectively based on the forecasted crime trends. Increase law enforcement presence and community policing efforts in areas with higher forecasted crime rates, particularly for battery crimes. Additionally, consider investing in crime prevention programs and initiatives aimed at addressing the root causes of crime.
#
# Public Awareness Campaigns: Launch public awareness campaigns to educate the community about crime prevention strategies and encourage reporting of suspicious activities. Engage with local communities to build trust and foster collaboration in combating crime.

# %%
#reporting quality visuals

# Plot Assault data
plt.figure(figsize=(10, 6))
assault_monthly.plot(label='Assault', color='blue')
plt.title('Monthly Assault Incidents')
plt.xlabel('Date')
plt.ylabel('Count')
plt.legend()
plt.show()

# Plot Battery data
plt.figure(figsize=(10, 6))
battery_monthly.plot(label='Battery', color='green')
plt.title('Monthly Battery Incidents')
plt.xlabel('Date')
plt.ylabel('Count')
plt.legend()
plt.show()
